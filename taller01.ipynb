# %% [markdown]
# # Taller 0-1 Notebook
# * Google Colab
# * Kaggle
# * Visual Studio Code
#
# Crear repositorio a Github! Subir al aula virtual link de repo **público**.

# %% [markdown]
# ## Enlaces interés
# * https://gitmoji.dev/
# * https://github.com/Ediixx/taller1

# %% [markdown]
# ## TAREA GRAFICAR
# $y(x) = x^3-7x^2+4x+12$
#
# ## Recomendaciones
# * Hacer tabla
#
# | i | x | y |
# |---|---|---|
# | 0 | -18 | ? |
# | 1 | 0 | ? |
# | 2 | 18 | ? |

# %%
# y(x) = x^3-7x^2+4x+12
def eqn (x: int)-> int:
    return x**3 - 7*x**2 + 4*x + 12
# ** simbolo de potencia en python, no se usa el '^'

# %%
# generacion de puntos para la gráfica
import numpy as np

## TAREA generar 100 datos del -10 al 10
Xs, step = np.linspace(-18,18, num=20, retstep=True)

# %%
Ys = []
for x in Xs:
    y = eqn(x)
    # Xs.append(x)
    Ys.append(y)
    print(f"x = {x:.2f} \ty = {y:.2e}")
Ys
# Out:
# x = -18.00 	y = -9.23e+03
# x = -16.11 	y = -6.91e+03
# x = -14.21 	y = -5.01e+03
# x = -12.32 	y = -3.49e+03
# x = -10.42 	y = -2.30e+03
# x = -8.53 	y = -1.42e+03
# x = -6.63 	y = -7.83e+02
# x = -4.74 	y = -3.65e+02
# x = -2.84 	y = -1.21e+02
# x = -0.95 	y = -1.04e+01
# x = 0.95 	y = 8.40e+00
# x = 2.84 	y = -2.42e+01
# x = 4.74 	y = -6.75e+01
# x = 6.63 	y = -8.05e+01
# x = 8.53 	y = -2.24e+01
# x = 10.42 	y = 1.48e+02
# x = 12.32 	y = 4.70e+02
# x = 14.21 	y = 9.86e+02
# x = 16.11 	y = 1.74e+03
# x = 18.00 	y = 2.76e+03
# [-9226.0,
#  -6908.117509841083,
#  -5008.9456188948825,
#  -3487.671380667736,
#  -2303.481848665987,
#  -1415.5640763959764,
#  -783.1051173640474,
#  -365.292025076542,
#  -121.3118530398018,
#  -10.351654760169183,
#  8.401516256014006,
#  -24.239393497594392,
#  -67.46143752733636,
#  -80.45166933955385,
#  -22.39714244058915,
#  147.51508966321592,
#  470.09797346551926,
#  986.1644554599791,
#  1736.5274821402518,
#  2762.0]

# %%
from matplotlib import pyplot as plt

# import seaborn as sns ## alternativa chévere

_ =plt.plot(Xs,Ys,marker = ".", color = "blue", linestyle = ":")
_ =plt.xlabel("Eje x")
_ =plt.ylabel("Eje y")
plt.title("Gráfica de función cúbica")
plt.grid()
plt.legend(["$y(x) = x^3-7x^2+4x+12$"])
plt.show()

# %% [markdown]
# ## TAREA GRAFICAR
# $y(x) = 18x^2+10x+25$
#
# ## Recomendaciones
# * Hacer tabla
#
# | i | x | y |
# |---|---|---|
# | 0 | -30 | ? |
# | 1 | 0 | ? |
# | 2 | 30 | ? |

# %%
def eqn (x: int)-> int:
    return 18*x**2+10*x+25

# %%
import numpy as np

Xs, step = np.linspace(-30,30, num=50, retstep=True)

# %%
Ys = []
for x in Xs:
    y = eqn(x)
    # Xs.append(x)
    Ys.append(y)
    print(f"x = {x:.2f} \ty = {y:.2e}")
Ys
# Out:
# x = -30.00 	y = 1.59e+04
# x = -28.78 	y = 1.46e+04
# x = -27.55 	y = 1.34e+04
# x = -26.33 	y = 1.22e+04
# x = -25.10 	y = 1.11e+04
# x = -23.88 	y = 1.00e+04
# x = -22.65 	y = 9.04e+03
# x = -21.43 	y = 8.08e+03
# x = -20.20 	y = 7.17e+03
# x = -18.98 	y = 6.32e+03
# x = -17.76 	y = 5.52e+03
# x = -16.53 	y = 4.78e+03
# x = -15.31 	y = 4.09e+03
# x = -14.08 	y = 3.45e+03
# x = -12.86 	y = 2.87e+03
# x = -11.63 	y = 2.34e+03
# x = -10.41 	y = 1.87e+03
# x = -9.18 	y = 1.45e+03
# x = -7.96 	y = 1.09e+03
# x = -6.73 	y = 7.74e+02
# x = -5.51 	y = 5.16e+02
# x = -4.29 	y = 3.13e+02
# x = -3.06 	y = 1.63e+02
# x = -1.84 	y = 6.74e+01
# x = -0.61 	y = 2.56e+01
# x = 0.61 	y = 3.79e+01
# x = 1.84 	y = 1.04e+02
# x = 3.06 	y = 2.24e+02
# x = 4.29 	y = 3.98e+02
# x = 5.51 	y = 6.27e+02
# x = 6.73 	y = 9.09e+02
# x = 7.96 	y = 1.24e+03
# x = 9.18 	y = 1.63e+03
# x = 10.41 	y = 2.08e+03
# x = 11.63 	y = 2.58e+03
# x = 12.86 	y = 3.13e+03
# x = 14.08 	y = 3.74e+03
# x = 15.31 	y = 4.40e+03
# x = 16.53 	y = 5.11e+03
# x = 17.76 	y = 5.88e+03
# x = 18.98 	y = 6.70e+03
# x = 20.20 	y = 7.57e+03
# x = 21.43 	y = 8.50e+03
# x = 22.65 	y = 9.49e+03
# x = 23.88 	y = 1.05e+04
# x = 25.10 	y = 1.16e+04
# x = 26.33 	y = 1.28e+04
# x = 27.55 	y = 1.40e+04
# x = 28.78 	y = 1.52e+04
# x = 30.00 	y = 1.65e+04
# [15925.0,
#  14641.784673052896,
#  13412.546855476883,
#  12237.286547271971,
#  11116.003748438148,
#  10048.698458975428,
#  9035.370678883799,
#  8076.020408163266,
#  7170.647646813828,
#  6319.252394835484,
#  5521.834652228237,
#  4778.394418992087,
#  4088.9316951270303,
#  3453.446480633069,
#  2871.9387755102043,
#  2344.4085797584335,
#  1870.8558933777592,
#  1451.28071636818,
#  1085.6830487296957,
#  774.0628904623072,
#  516.4202415660137,
#  312.7551020408162,
#  163.0674718867139,
#  67.35735110370668,
#  25.624739691795078,
#  37.86963765097874,
#  104.09204498125794,
#  224.29196168263226,
#  398.4693877551019,
#  626.6243231986667,
#  908.7567680133286,
#  1244.8667221990845,
#  1634.9541857559352,
#  2079.019158683882,
#  2577.061640982923,
#  3129.081632653063,
#  3735.0791336942957,
#  4395.0541441066225,
#  5109.006663890045,
#  5876.936693044563,
#  6698.844231570183,
#  7574.729279466891,
#  8504.591836734695,
#  9488.431903373596,
#  10526.24947938359,
#  11618.04456476468,
#  12763.817159516871,
#  13963.567263640154,
#  15217.294877134527,
#  16525.0]

# %%
from matplotlib import pyplot as plt

_ =plt.plot(Xs,Ys,marker = "+", color = "green", linestyle = "-")
_ =plt.xlabel("Eje x")
_ =plt.ylabel("Eje y")
plt.title("Gráfica de función cuadrática")
plt.grid()
plt.legend(["$Y(x) = 18*x**2+10*x+25$"])
plt.show()
