# %% [markdown]
# # Taller 0-1 Notebook
# * Google Colab
# * Kaggle
# * Visual Studio Code
#
# Crear repositorio a Github! Subir al aula virtual link de repo **público**.

# %% [markdown]
# ## Enlaces interés
# * https://gitmoji.dev/
# * https://github.com/Ediixx/taller1

# %% [markdown]
# ## TAREA GRAFICAR
# $y(x) = x^3-7x^2+4x+12$
#
# ## Recomendaciones
# * Hacer tabla
#
# | i | x | y |
# |---|---|---|
# | 0 | -5 | ? |
# | 1 | 0 | ? |
# | 2 | 5 | ? |

# %%
# y(x) = x^3-7x^2+4x+12
def eqn (x: int)-> int:
    # ** simbolo de potencia en python, no se usa el '^' como en otros lenguajes
    return x**3 - 7*x**2 + 4*x + 12

# %%
# generacion de puntos para la gráfica
import numpy as np

## TAREA generar 100 datos del -10 al 10
Xs, step = np.linspace(-10,10, num=100, retstep=True)

# %%
Ys = []
for x in Xs:
    y = eqn(x)
    # Xs.append(x)
    Ys.append(y)
    print(f"x = {x:.2f} \ty = {y:.2e}")
Ys
# Out:
# x = -10.00 	y = -1.73e+03
# x = -9.80 	y = -1.64e+03
# x = -9.60 	y = -1.55e+03
# x = -9.39 	y = -1.47e+03
# x = -9.19 	y = -1.39e+03
# x = -8.99 	y = -1.32e+03
# x = -8.79 	y = -1.24e+03
# x = -8.59 	y = -1.17e+03
# x = -8.38 	y = -1.10e+03
# x = -8.18 	y = -1.04e+03
# x = -7.98 	y = -9.74e+02
# x = -7.78 	y = -9.13e+02
# x = -7.58 	y = -8.55e+02
# x = -7.37 	y = -7.99e+02
# x = -7.17 	y = -7.46e+02
# x = -6.97 	y = -6.94e+02
# x = -6.77 	y = -6.46e+02
# x = -6.57 	y = -5.99e+02
# x = -6.36 	y = -5.55e+02
# x = -6.16 	y = -5.12e+02
# x = -5.96 	y = -4.72e+02
# x = -5.76 	y = -4.34e+02
# x = -5.56 	y = -3.98e+02
# x = -5.35 	y = -3.63e+02
# x = -5.15 	y = -3.31e+02
# x = -4.95 	y = -3.01e+02
# x = -4.75 	y = -2.72e+02
# x = -4.55 	y = -2.45e+02
# x = -4.34 	y = -2.19e+02
# x = -4.14 	y = -1.96e+02
# x = -3.94 	y = -1.74e+02
# x = -3.74 	y = -1.53e+02
# x = -3.54 	y = -1.34e+02
# x = -3.33 	y = -1.16e+02
# x = -3.13 	y = -9.99e+01
# x = -2.93 	y = -8.49e+01
# x = -2.73 	y = -7.13e+01
# ...

# %%
from matplotlib import pyplot as plt

# import seaborn as sns ## alternativa chévere

_ =plt.plot(Xs,Ys)
_ =plt.xlabel("Eje x")
_ =plt.ylabel("Eje y")
plt.title("Gráfica de función cúbica")
plt.grid()
plt.legend(["$y(x) = x^3-7x^2+4x+12$"])
plt.show()
